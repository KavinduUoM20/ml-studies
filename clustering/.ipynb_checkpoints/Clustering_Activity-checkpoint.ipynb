# %% [markdown]
# # **Clustering Coding Acitivity**

# %% [markdown]
# ### **List of Group Members**
#
# 206116L KM Senevirathne
#
# 206087V PGLK Pannipitiya
#
# ---

# %% [markdown]
# Consider the planet data stored in the `planet.csv` file. These data give values of three features for 101 exoplanets discovered up to October 2002. We are interested in clustering the exoplanets based on these features. Note that an exoplanet is a planet located outside the solar system. You may read about them at https://en.wikipedia.org/wiki/Exoplanet. The features recorded are - `Mass` (in Jupiter mass), `Period` (in Earth days), and `Eccentricity`.

# %% [markdown]
# **a)  Perform an exploratory analysis of the data. Be sure to examine the univariate distributions of the variables and their bivariate relationships using appropriate plots and summary statistics.**

# %% [markdown]
# Checkout Section (1)

# %% [markdown]
# **b)  Do you think standardizing the variables before clustering would be a good idea? Justify your answer.**

# %% [markdown]
# Yes. because Standardizing,
#
# *1. Ensures Equal Weighting -* Prevents variables with larger ranges from dominating distance calculations, leading to more balanced clustering.
#
# *2. Improves Algorithm Performance -* Enhances the effectiveness of distance-based algorithms (e.g., K-Means, Hierarchical clustering, DBSCAN) by achieving more meaningful clusters.
#
# *3. Facilitates Comparison -* Allows straightforward comparison of each variable's contribution to clusters, especially for features with different units or ranges.
#
# *4. Prevents Bias -* Avoids undue influence of larger scale variables on cluster centroids, resulting in unbiased clustering outcomes.

# %% [markdown]
# **c)  Would you use metric-based or correlation-based distance to cluster the exoplanets? Justify your answer.**

# %% [markdown]
# For this exoplanet scenario, ***correlation-based distance*** might be more appropriate due to following reasons.
#
# 1. In astronomical data, the relationships between variables can be more meaningful than their absolute values. For example, an exoplanet’s mass and period might have a specific correlation that indicates an underlying physical relationship.
#
# 2. Mass, Period, and Eccentricity are likely measured on different scales and units. Correlation-based distance will normalize these differences, clustering based on how the features relate rather than their raw values.

# %% [markdown]
# **d)  Regardless of your answers in (b) and (c), standardize the variables and hierarchically cluster the exoplanets using complete linkage and Euclidean distance. Display the results using a dendogram. Cut the dendogram at a height that results in three distinct clusters. Summarize the cluster-specific means of the three variables (on the original scale) in a tabular form. Also, make pairwise scatterplots of the three variables (on the original scale) and show the three clusters in different colors.**

# %% [markdown]
# Checkout Section (2),and (3)

# %% [markdown]
# **e)  Repeat (d) using $K$-means clustering with $K=3$. (Of course, you won't have a dendogram in this case.) Compare the conclusions with (d).**

# %% [markdown]
# Checkout Section (4),and (5)

# %% [markdown]
# ### **Import Dependancies**

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from scipy.cluster.hierarchy import linkage, dendrogram, fcluster
from sklearn.metrics import adjusted_rand_score, silhouette_score
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('./data/planet.csv')

# %%
df.head()
# Out:
#     Mass  Period  Eccentricity
# 0  0.120   4.950          0.00
# 1  0.197   3.971          0.00
# 2  0.210  44.280          0.34
# 3  0.220  75.800          0.28
# 4  0.230   6.403          0.08

# %%
df.shape
# Out:
# (101, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101 entries, 0 to 100
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Mass          101 non-null    float64
#  1   Period        101 non-null    float64
#  2   Eccentricity  101 non-null    float64
# dtypes: float64(3)
# memory usage: 2.5 KB

# %%
# Null value count
df.isnull().sum()
# Out:
# Mass            0
# Period          0
# Eccentricity    0
# dtype: int64

# %% [markdown]
# ### **1) Exploratory Data Analysis (EDA)**

# %%
# Summary
df.describe()
# Out:
#              Mass       Period  Eccentricity
# count  101.000000   101.000000    101.000000
# mean     3.327287   666.531252      0.281548
# std      3.680601   873.749838      0.210943
# min      0.050000     2.985000      0.000000
# 25%      0.930000    44.280000      0.100000
# 50%      1.760000   337.110000      0.270000
# 75%      4.140000  1089.000000      0.410000
# max     17.500000  5360.000000      0.927000

# %% [markdown]
# #### Check Distributions

# %%
# Create subplots
fig, axes = plt.subplots(1, 3, figsize=(15, 5))

# Plot histograms
df['Mass'].plot(kind='hist', ax=axes[0], title='Mass')
df['Period'].plot(kind='hist', ax=axes[1], title='Period')
df['Eccentricity'].plot(kind='hist', ax=axes[2], title='Eccentricity')

# Show the plot
plt.tight_layout()
plt.show()

# %%
# Box plots
fig, axes = plt.subplots(1, 3, figsize=(15, 5))

# Plot boxplots
df.boxplot(column='Mass', ax=axes[0])
axes[0].set_title('Mass')

df.boxplot(column='Period', ax=axes[1])
axes[1].set_title('Period')

df.boxplot(column='Eccentricity', ax=axes[2])
axes[2].set_title('Eccentricity')

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Check PDFs

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 5))

# Plot KDE plots with Seaborn
sns.kdeplot(df['Mass'], ax=axes[0])
axes[0].set_title('Mass')

sns.kdeplot(df['Period'], ax=axes[1])
axes[1].set_title('Period')

sns.kdeplot(df['Eccentricity'], ax=axes[2])
axes[2].set_title('Eccentricity')

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Check Bivariate Relationships

# %%
# Pair plot
sns.pairplot(df)
plt.suptitle('Pair Plot',y=1.02)
plt.show()

# %%
# Correlation matrix
correlation_matrix = df.corr()
correlation_matrix
# Out:
#                   Mass    Period  Eccentricity
# Mass          1.000000  0.268409      0.304933
# Period        0.268409  1.000000      0.144593
# Eccentricity  0.304933  0.144593      1.000000

# %%
# Heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation Matrix Heatmap')
plt.show()

# %% [markdown]
# ### **2) Standardizing**

# %%
scaler = StandardScaler()
df_scaled = scaler.fit_transform(df)

# %% [markdown]
# ### **3) Hierarchical Clustering**

# %%
# Hierarchical clustering
linkage_matrix = linkage(df_scaled, method='complete', metric='euclidean')

# %%
# Visualize
plt.figure(figsize=(10, 6))
dendrogram(linkage_matrix)
plt.title('Dendrogram of Exoplanets')
plt.xlabel('Exoplanets')
plt.ylabel('Euclidean Distance')
plt.show()

# %%
# Extract three clusters
clusters = fcluster(linkage_matrix, 3, criterion='maxclust')

# %%
# Assign cluster labels
df['HCresults'] = clusters

# %%
# Calculate cluster-specific means
cluster_means = df.groupby('HCresults').mean()
cluster_means
# Out:
#                Mass       Period  Eccentricity
# HCresults
# 1          1.703316   488.747927      0.070771
# 2          4.311774   699.794116      0.412694
# 3          4.000000  5360.000000      0.160000

# %%
# Pairwise scatterplots
sns.pairplot(df, hue='HCresults', palette='Set1')
plt.suptitle('Pairwise Scatterplots')
plt.show()

# %% [markdown]
# ### **4) K-Means Clustering**

# %%
# K-means clustering with K=3
kmeans = KMeans(n_clusters=3, random_state=42)
kmeans.fit(df_scaled)
# Out:
# KMeans(n_clusters=3, random_state=42)

# %%
# Assign cluster labels to the original DataFrame
df['KMCresults'] = kmeans.labels_

# %%
# cluster-specific means 
cluster_means = df.groupby('KMCresults').mean()
cluster_means
# Out:
#                  Mass       Period  Eccentricity  HCresults
# KMCresults
# 0            2.334857  1027.686886      0.427229   1.885714
# 1           10.287059  1136.816129      0.430000   2.000000
# 2            1.621551   245.402882      0.125986   1.326531

# %%
# Pairwise scatterplots 
sns.pairplot(df, hue='KMCresults', palette='Set1')
plt.suptitle('Pairwise Scatterplots')
plt.show()

# %% [markdown]
# ### **5) Comparing Results**

# %%
df.head()
# Out:
#     Mass  Period  Eccentricity  HCresults  KMCresults
# 0  0.120   4.950          0.00          1           2
# 1  0.197   3.971          0.00          1           2
# 2  0.210  44.280          0.34          2           2
# 3  0.220  75.800          0.28          2           2
# 4  0.230   6.403          0.08          1           2

# %%
hierarchical_clusters = df['HCresults']
kmeans_clusters = df['KMCresults']

# %% [markdown]
# #### Adjusted Rand Index (ARI)

# %%
# Adjusted Rand Index (ARI)
ari = adjusted_rand_score(hierarchical_clusters, kmeans_clusters)
print(f"Adjusted Rand Index (ARI): {ari}")
# Out:
# Adjusted Rand Index (ARI): 0.1734490011088663

# %% [markdown]
# **Interpretation**
#
# ARI of 0.173 indicates a low to moderate level of agreement between the clustering results from hierarchical clustering and K-means clustering.
#
# It suggests that there is some similarity between the clusters identified by the two methods, but there are also significant differences or inconsistencies.

# %% [markdown]
# #### Silhouette Score

# %%
# Silhouette Score for K-means clustering
silhouette_score_kmeans = silhouette_score(df_scaled, kmeans_clusters)
print(f"Silhouette Score (K-means): {silhouette_score_kmeans}")
# Out:
# Silhouette Score (K-means): 0.33673351158255765

# %%
# Silhouette Score for Hierarchical clustering
silhouette_score_hierarchical = silhouette_score(df_scaled, hierarchical_clusters)
print(f"Silhouette Score (Hierarchical): {silhouette_score_hierarchical}")
# Out:
# Silhouette Score (Hierarchical): 0.25180561304757865

# %% [markdown]
# **Interpretation**
#
# The Silhouette Score for K-means clustering (0.337) suggests that the clusters identified by K-means have a moderate level of separation and coherence.
#
# The Silhouette Score for hierarchical clustering (0.252) indicates a slightly lower level of cluster separation compared to K-means.

# %% [markdown]
# #### Conclusion

# %% [markdown]
# K-means clustering appears to have slightly better-defined clusters, as indicated by its higher Silhouette Score.
